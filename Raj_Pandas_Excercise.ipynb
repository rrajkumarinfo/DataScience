# %% [markdown]
# Import the pandas library
# Read the data company.csv in pandas

# %%
import pandas as pd
data=pd.read_csv("company.csv")
data
# Out:
#      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %% [markdown]
# Find the dimension of given data

# %%
data.shape
# Out:
# (148, 6)

# %% [markdown]
# List down all the columns in data frame

# %%
data.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %% [markdown]
# List the top 10 rows in datframe

# %%
data.head(10)
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0
# 5  Infosys   NaN  5000.0  Calcutta   India       0
# 6      TCS   NaN  6000.0   Chennai   India       1
# 7  Infosys  23.0  7000.0    Mumbai   India       1
# 8      TCS  34.0  8000.0  Calcutta   India       1
# 9      CTS  45.0  9000.0     Delhi   India       0

# %% [markdown]
# List the last 15 rows in datframe

# %%
data.tail(15)
# Out:
#                        Company   Age  Salary      Place Country  Gender
# 133                        NaN  22.0  8943.0    Chennai   India       0
# 134  Tata Consultancy Services  31.0  8345.0     Mumbai   India       0
# 135                        CTS  40.0  9284.0   Calcutta   India       1
# 136                        NaN   NaN     NaN      Delhi   India       0
# 137                        CTS  31.0  2034.0     Mumbai   India       0
# 138                        CTS  44.0  3033.0     Cochin   India       0
# 139                 Congnizant  22.0  2934.0      Noida   India       0
# 140                    Infosys  44.0  4034.0  Hyderabad   India       0
# 141                        TCS  33.0  5034.0   Calcutta   India       0
# 142            Infosys Pvt Lmt  22.0  8202.0     Mumbai   India       0
# 143                        TCS  33.0  9024.0   Calcutta   India       1
# 144                    Infosys  22.0  8787.0   Calcutta   India       1
# 145                    Infosys  44.0  4034.0      Delhi   India       1
# 146                        TCS  33.0  5034.0     Mumbai   India       1
# 147                    Infosys  22.0  8202.0     Cochin   India       0

# %% [markdown]
# Find the number of rows in dataframe

# %%
len(data.index)
# Out:
# 148

# %% [markdown]
# Check the information of dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
#  5   Gender   148 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.1+ KB

# %% [markdown]
# Check the basic Statistics of Dataframe. Give your inference from the stats

# %%
data.describe()
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %% [markdown]
# Retrieve 20 to 100 rows and Company and age usig iloc

# %%
data[['Company','Age']].iloc[20:100]
# Out:
#      Company   Age
# 26       TCS  34.0
# 27       CTS  45.0
# 28       CTS  23.0
# 29       CTS  35.0
# 30       CTS  46.0
# ..       ...   ...
# 116      TCS  33.0
# 117      CTS  44.0
# 119      CTS  33.0
# 121      CTS   0.0
# 122  Infosys  44.0
#
# [80 rows x 2 columns]

# %% [markdown]
# Retrieve 20 to 100 rows and Company and age usig loc

# %%
data[['Company','Age']].loc[20:100]
# Out:
#      Company   Age
# 20       TCS  37.0
# 21   Infosys  50.0
# 22       TCS  21.0
# 23   Infosys   NaN
# 24       TCS   NaN
# ..       ...   ...
# 96       TCS   NaN
# 97   Infosys  22.0
# 98       TCS  33.0
# 99       CTS  44.0
# 100      CTS  22.0
#
# [81 rows x 2 columns]

# %% [markdown]
# Chage the data in 100 row and Place as 'Noida'

# %%
data.loc[100]
# Out:
# Company       CTS
# Age            22
# Salary        NaN
# Place      Cochin
# Country     India
# Gender          0
# Name: 100, dtype: object

# %%
data.loc[100,'Place'] = 'Noida'

# %%
data.loc[100]
# Out:
# Company      CTS
# Age           22
# Salary       NaN
# Place      Noida
# Country    India
# Gender         0
# Name: 100, dtype: object

# %%
data.rename(columns={'Place':'City'},inplace=True)

# %% [markdown]
# Change the column 'Place' to 'City'

# %%
data.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'City', 'Country', 'Gender'], dtype='object')

# %% [markdown]
# List down the unique data in each columns and find length of unique data

# %%
data.nunique()
# Out:
# Company     7
# Age        29
# Salary     40
# City       11
# Country     1
# Gender      2
# dtype: int64

# %%
data
# Out:
#      Company   Age  Salary      City Country  Gender
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# 5    Infosys   NaN  5000.0  Calcutta   India       0
# 6        TCS   NaN  6000.0   Chennai   India       1
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [124 rows x 6 columns]

# %%
data['Company'].unique()
# Out:
# array(['TCS', 'Infosys', 'CTS', nan, 'Tata Consultancy Services',
#        'Congnizant', 'Infosys Pvt Lmt'], dtype=object)

# %%
data
# Out:
#      Company   Age  Salary      City Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %% [markdown]
# Rename all the possible labels of column in Company as three labels
# TCS
# CTS
# Infosys

# %%
data['Company'].replace({"Congnizant":'CTS', "Tata Consultancy Services":'TCS',"Infosys Pvt Lmt":'Infosys'},inplace=True)
data["Company"].value_counts()
# Out:
# TCS        55
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %%
# Out:
# TCS        55
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %%
data["Age"].unique()
# Out:
# array([35., 40., 23., nan, 34., 45., 18., 37., 50., 21., 46., 20., 36.,
#        26., 41., 24., 25., 32., 19., 38., 51., 31., 43., 44., 33., 17.,
#         0., 54., 22., 30.])

# %%
data["Age"].replace({0:'NA'},inplace=True)

# %%
data["Age"].unique()
# Out:
# array([35.0, 40.0, 23.0, nan, 34.0, 45.0, 18.0, 37.0, 50.0, 21.0, 46.0,
#        20.0, 36.0, 26.0, 41.0, 24.0, 25.0, 32.0, 19.0, 38.0, 51.0, 31.0,
#        43.0, 44.0, 33.0, 17.0, 'NA', 54.0, 22.0, 30.0], dtype=object)

# %%
data
# Out:
#      Company Age  Salary      City Country  Gender
# 0        TCS  20     NaN   Chennai   India       0
# 1    Infosys  30     NaN    Mumbai   India       0
# 2        TCS  35  2300.0  Calcutta   India       0
# 3    Infosys  40  3000.0     Delhi   India       0
# 4        TCS  23  4000.0    Mumbai   India       0
# ..       ...  ..     ...       ...     ...     ...
# 143      TCS  33  9024.0  Calcutta   India       1
# 144  Infosys  22  8787.0  Calcutta   India       1
# 145  Infosys  44  4034.0     Delhi   India       1
# 146      TCS  33  5034.0    Mumbai   India       1
# 147  Infosys  22  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %% [markdown]
# Where ever you see age as 0 replace with NA
#
# ##Hint df[df.Age==20] = np.isnan

# %%
data.duplicated().value_counts()
# Out:
# False    121
# True       3
# dtype: int64

# %%
data[data.duplicated()].value_counts()
# Out:
# Company  Age   Salary  City      Country  Gender
# TCS      21.0  4824.0  Mumbai    India    0         1
# Infosys  22.0  8787.0  Calcutta  India    1         1
# dtype: int64

# %% [markdown]
# Check how many duplicated data is there?

# %%
data[data.duplicated()]
# Out:
#      Company  Age  Salary      City Country  Gender
# 130      TCS   21  4824.0    Mumbai   India       0
# 131  Infosys  NaN  5835.0    Mumbai   India       0
# 144  Infosys   22  8787.0  Calcutta   India       1

# %% [markdown]
# Remove all duplicated rowise data

# %%
data=data.drop_duplicates()

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Company, Age, Salary, City, Country, Gender]
# Index: []

# %% [markdown]
# Remove the column 'Country'

# %%
data
# Out:
#      Company  Age  Salary      City Country  Gender
# 2        TCS   35  2300.0  Calcutta   India       0
# 3    Infosys   40  3000.0     Delhi   India       0
# 4        TCS   23  4000.0    Mumbai   India       0
# 5    Infosys  NaN  5000.0  Calcutta   India       0
# 6        TCS  NaN  6000.0   Chennai   India       1
# ..       ...  ...     ...       ...     ...     ...
# 142  Infosys   22  8202.0    Mumbai   India       0
# 143      TCS   33  9024.0  Calcutta   India       1
# 145  Infosys   44  4034.0     Delhi   India       1
# 146      TCS   33  5034.0    Mumbai   India       1
# 147  Infosys   22  8202.0    Cochin   India       0
#
# [121 rows x 6 columns]

# %%
data=data.drop(columns=['Country'])

# %%
data
# Out:
#      Company  Age  Salary      City  Gender
# 2        TCS   35  2300.0  Calcutta       0
# 3    Infosys   40  3000.0     Delhi       0
# 4        TCS   23  4000.0    Mumbai       0
# 5    Infosys  NaN  5000.0  Calcutta       0
# 6        TCS  NaN  6000.0   Chennai       1
# ..       ...  ...     ...       ...     ...
# 142  Infosys   22  8202.0    Mumbai       0
# 143      TCS   33  9024.0  Calcutta       1
# 145  Infosys   44  4034.0     Delhi       1
# 146      TCS   33  5034.0    Mumbai       1
# 147  Infosys   22  8202.0    Cochin       0
#
# [121 rows x 5 columns]

# %% [markdown]
# Remove the row number 137

# %%
# Out:
#      Company  Age Salary        City Country Gender
# 0        TCS   20    NaN     Chennai   India      0
# 1    Infosys   30    NaN      Mumbai   India      0
# 2        TCS   35   2300    Calcutta   India      0
# 3    Infosys   40   3000       Delhi   India      0
# 4        TCS   23   4000      Mumbai   India      0
# 5    Infosys  NaN   5000    Calcutta   India      0
# 6        TCS  NaN   6000     Chennai   India      1
# 7    Infosys   23   7000      Mumbai   India      1
# 8        TCS   34   8000    Calcutta   India      1
# 9        CTS   45   9000       Delhi   India      0
# 10       CTS   23    NaN      Mumbai   India      0
# 11       CTS   34   1089    Calcutta   India      0
# 12       CTS   45    NaN     Chennai   India      0
# 13       CTS   18   1234      Mumbai   India      0
# 14   Infosys   40   3000    Calcutta   India      0
# 15       TCS   23   3000       Delhi   India      0
# 16   Infosys   23   3030  Podicherry   India      0
# 17       TCS   34   5000      Cochin   India      0
# 18       TCS   22    NaN     Chennai   India      0
# 19   Infosys   32    NaN      Mumbai   India      0
# 20       TCS   37   3045    Calcutta   India      0
# 21   Infosys   50   3184       Delhi   India      0
# 22       TCS   21   4824      Mumbai   India      0
# 23   Infosys  NaN   5835      Cochin   India      0
# 24       TCS  NaN   7084     Chennai   India      1
# 25   Infosys   23   8943      Mumbai   India      1
# 26       TCS   34   8345    Calcutta   India      1
# 27       CTS   45   9284       Delhi   India      1
# 28       CTS   23   9876      Mumbai   India      1
# 29       CTS   35   2034      Cochin   India      0
# ..       ...  ...    ...         ...     ...    ...
# 113  Infosys  NaN   5435     Chennai   India      0
# 114      TCS  NaN   5555      Mumbai   India      0
# 115  Infosys   22   8787    Calcutta   India      0
# 116      TCS   33   8787         NaN   India      1
# 117      CTS   44   9876         NaN   India      1
# 118      CTS   22    NaN         NaN   India      0
# 119      CTS   33   1089       Noida   India      0
# 120      CTS   44    NaN   Hyderabad   India      0
# 122  Infosys   44   3234      Mumbai   India      0
# 123      NaN  NaN   3454    Calcutta   India      0
# 124  Infosys   22   8787    Calcutta   India      1
# 125      TCS   33   5654         NaN   India      1
# 126      TCS   20   5009         NaN   India      1
# 127  Infosys   30   5098       Noida   India      0
# 128      TCS   33   3045   Hyderabad   India      0
# 129  Infosys   50   3184    Calcutta   India      0
# 132      TCS  NaN   7084      Cochin   India      1
# 133      NaN   22   8943     Chennai   India      0
# 134      TCS   31   8345      Mumbai   India      0
# 135      CTS   40   9284    Calcutta   India      1
# 137      CTS   31   2034      Mumbai   India      0
# 138      CTS   44   3033      Cochin   India      0
# 139      CTS   22   2934       Noida   India      0
# 140  Infosys   44   4034   Hyderabad   India      0
# 141      TCS   33   5034    Calcutta   India      0
# 142  Infosys   22   8202      Mumbai   India      0
# 143      TCS   33   9024    Calcutta   India      1
# 145  Infosys   44   4034       Delhi   India      1
# 146      TCS   33   5034      Mumbai   India      1
# 147  Infosys   22   8202      Cochin   India      0
#
# [138 rows x 6 columns]

# %%
data= data.drop(137)

# %%
data.loc[135:138]
# Out:
#     Company Age  Salary      City  Gender
# 135     CTS  40  9284.0  Calcutta       1
# 138     CTS  44  3033.0    Cochin       0

# %% [markdown]
# Find number of each labels in Company

# %%
# Out:
# TCS                52
# Infosys            43
# CTS                35
# <ufunc 'isnan'>     1
# Name: Company, dtype: int64

# %%
data.Company.value_counts()
# Out:
# TCS                                                                                                                                                                                                                                                        48
# Infosys                                                                                                                                                                                                                                                    41
# CTS                                                                                                                                                                                                                                                        26
# <bound method Series.mode of 2          TCS\n3      Infosys\n4          TCS\n5      Infosys\n6          TCS\n        ...   \n143        TCS\n144    Infosys\n145    Infosys\n146        TCS\n147    Infosys\nName: Company, Length: 124, dtype: object>     5
# Name: Company, dtype: int64

# %% [markdown]
# Find number of each labels in City

# %%
data.City.value_counts()
# Out:
# Calcutta      27
# Mumbai        26
# Cochin        12
# Delhi         12
# Chennai       11
# Noida          7
# Hyderabad      6
# Podicherry     3
# Pune           1
# Nagpur         1
# Bhopal         1
# Name: City, dtype: int64

# %% [markdown]
# Find Number of Null Values in each column

# %%
# Out:
# Company     8
# Age        17
# Salary     23
# City       14
# Country     0
# Gender      0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Company     0
# Age        16
# Salary      0
# City       13
# Gender      0
# dtype: int64

# %% [markdown]
# Remove all Null values in Salary

# %%
data.dropna(subset=['Salary'],inplace=True)

# %%
# Out:
#      Company   Age  Salary     Place Country  Gender
# 0        TCS  20.0     NaN   Chennai   India       0
# 1    Infosys  30.0     NaN    Mumbai   India       0
# 2        TCS  35.0  2300.0  Calcutta   India       0
# 3    Infosys  40.0  3000.0     Delhi   India       0
# 4        TCS  23.0  4000.0    Mumbai   India       0
# ..       ...   ...     ...       ...     ...     ...
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0
#
# [148 rows x 6 columns]

# %% [markdown]
# Replace the Null values in Comapany with mode

# %%
data["Company"].fillna(data["Company"].mode,inplace=True)

# %%
data["Company"].mode()
# Out:
# 0    TCS
# dtype: object

# %%
data['Company'].unique()
# Out:
# array(['TCS', 'Infosys', 'CTS',
#        <bound method Series.mode of 2          TCS
# 3      Infosys
# 4          TCS
# 5      Infosys
# 6          TCS
#         ...
# 143        TCS
# 144    Infosys
# 145    Infosys
# 146        TCS
# 147    Infosys
# Name: Company, Length: 124, dtype: object>], dtype=object)

# %% [markdown]
# Replace the null value in Salary with median

# %%
data["Salary"].median()
# Out:
# 5000.0

# %%
data["Salary"].fillna(data["Salary"].median(),inplace=True)

# %%
data["Age"].fillna(data["Age"].mean(),inplace=True)

# %% [markdown]
# Replace the null value in age with mean

# %% [markdown]
# Filter the data with age>40 and Salary<5000

# %%
data[(data["Age"] > 40) & (data["Salary"] < 5000)]
# Out:
#      Company   Age  Salary      Place Country  Gender
# 21   Infosys  50.0  3184.0      Delhi   India       0
# 32   Infosys  45.0  4034.0   Calcutta   India       0
# 39   Infosys  41.0  3000.0     Mumbai   India       0
# 50   Infosys  41.0  3000.0    Chennai   India       0
# 57   Infosys  51.0  3184.0  Hyderabad   India       0
# 68   Infosys  43.0  4034.0     Mumbai   India       0
# 75   Infosys  44.0  3000.0     Cochin   India       0
# 86   Infosys  41.0  3000.0      Delhi   India       0
# 93   Infosys  54.0  3184.0     Mumbai   India       0
# 104  Infosys  44.0  4034.0      Delhi   India       0
# 122  Infosys  44.0  3234.0     Mumbai   India       0
# 129  Infosys  50.0  3184.0   Calcutta   India       0
# 138      CTS  44.0  3033.0     Cochin   India       0
# 140  Infosys  44.0  4034.0  Hyderabad   India       0
# 145  Infosys  44.0  4034.0      Delhi   India       1

# %%
# %matplotlib inline

# %%
data.plot(kind)

# %% [markdown]
# Draw an histogram chart for age, Salary

# %%
data['Age'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['Salary'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Draw the pie chart for place and Company

# %%
data['Place'].unique()
# Out:
# array(['Chennai', 'Mumbai', 'Calcutta', 'Delhi', 'Podicherry', 'Cochin',
#        nan, 'Noida', 'Hyderabad', 'Bhopal', 'Nagpur', 'Pune'],
#       dtype=object)

# %%
data["Company"].unique()
# Out:
# array(['TCS', 'Infosys', 'CTS', nan], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
#  5   Gender   148 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.1+ KB

# %%
data['Company'].plot(kind = 'pie')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-338-97daddcd4d27> in <module>
# ----> 1 data['Company'].plot(kind = 'pie')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      58                 ax = plt.gca()
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      61     plot_obj.generate()
#      62     plot_obj.draw()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in __init__(self, data, kind, **kwargs)
#    1505     def __init__(self, data, kind=None, **kwargs):
#    1506         data = data.fillna(value=0)
# -> 1507         if (data < 0).any().any():
#    1508             raise ValueError(f"{kind} doesn't allow negative values")
#    1509         MPLPlot.__init__(self, data, kind=kind, **kwargs)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     242
#     243     elif is_object_dtype(lvalues.dtype):
# --> 244         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     245
#     246     else:
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      54         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      55     else:
# ---> 56         result = libops.scalar_compare(x.ravel(), y, op)
#      57     return result.reshape(x.shape)
#      58
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# Find the mean, count, median of salary with repective to the place

# %%
# Out:
#                         mean  count  median
# City
# <ufunc 'isnan'>  5009.000000      1  5009.0
# Bhopal           7000.000000      1  7000.0
# Calcutta         5115.400000     25  4824.0
# Chennai          5824.200000     10  5917.5
# Cochin           5053.000000     12  5017.0
# Delhi            4925.545455     11  4034.0
# Hyderabad        4382.833333      6  3609.0
# Mumbai           4895.269231     26  4429.0
# Nagpur           8000.000000      1  8000.0
# Noida            4387.000000      7  4000.0
# Podicherry       6157.000000      2  6157.0
# Pune             9000.000000      1  9000.0

# %%
data.groupby('Place').Salary.describe()
# Out:
#             count         mean          std     min      25%     50%      75%  \
# Place
# Bhopal        1.0  7000.000000          NaN  7000.0  7000.00  7000.0  7000.00
# Calcutta     28.0  5033.428571  2747.552816  1089.0  3022.50  4584.5  8086.25
# Chennai      11.0  6115.090909  2467.469694  1089.0  5217.50  6000.0  7928.00
# Cochin       12.0  5053.000000  2409.508249  1234.0  3024.75  5017.0  7226.50
# Delhi        12.0  4768.833333  2579.228526  2300.0  3000.00  3609.0  5836.25
# Hyderabad     6.0  4382.833333  2472.441095  2034.0  3079.75  3609.0  4758.50
# Mumbai       29.0  4867.931034  2438.647209  1089.0  3000.00  4824.0  6544.00
# Nagpur        1.0  8000.000000          NaN  8000.0  8000.00  8000.0  8000.00
# Noida         7.0  4387.000000  2350.403228  1089.0  2989.50  4000.0  5820.50
# Podicherry    3.0  4782.666667  3929.949788  2034.0  2532.00  3030.0  6157.00
# Pune          1.0  9000.000000          NaN  9000.0  9000.00  9000.0  9000.00
#
#                max
# Place
# Bhopal      7000.0
# Calcutta    9284.0
# Chennai     9024.0
# Cochin      8202.0
# Delhi       9284.0
# Hyderabad   9000.0
# Mumbai      9876.0
# Nagpur      8000.0
# Noida       8000.0
# Podicherry  9284.0
# Pune        9000.0

# %% [markdown]
# Find the mean age with repective to the Company

# %%
data.groupby('Company').Age.mean()
# Out:
# Company
# CTS        31.631579
# Infosys    32.051282
# TCS        28.659574
# Name: Age, dtype: float64
