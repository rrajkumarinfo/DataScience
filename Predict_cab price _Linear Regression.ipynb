# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split, KFold, cross_val_score


# %matplotlib inline

# %%
data=pd.read_csv("Predict Cab price.csv")

# %%
data
# Out:
#     miles  temp  rain  ncabs  price
# 0       1    30     0     10     20
# 1       1    38     0      5     40
# 2       1    25     0      1     50
# 3       1    20     1     10     50
# 4       1    15     1      4     80
# 5       1    10     1      2    200
# 6       2    30     0     10     30
# 7       2    38     0      5     50
# 8       2    25     0      1     90
# 9       2    20     1     10     90
# 10      2    15     1      4    120
# 11      2    10     1      2    250
# 12      3    30     0     10     50
# 13      3    38     0      5     80
# 14      3    25     0      1     96
# 15      3    20     1     10    110
# 16      3    15     1      4    122
# 17      3    10     1      2    333
# 18      4    30     0     10     87
# 19      4    38     0      5    144
# 20      4    25     0      1    170
# 21      4    20     1     10    255
# 22      4    15     1      4    180
# 23      4    10     1      2    424
# 24      5    30     0     10    144
# 25      5    38     0      5    176
# 26      5    25     0      1    189
# 27      5    20     1     10    232
# 28      5    15     1      4    270
# 29      5    10     1      2    555
# 30      1    31     0     11     22
# 31      1    37     0      4     44
# 32      1    24     0      1     55
# 33      1    21     1     11     55
# 34      1    14     1      6     88
# 35      1    11     1      3    201
# 36      2    32     0     11     33
# 37      2    39     0      5     55
# 38      2    23     0      1     90
# 39      2    21     1     10     98
# 40      2    18     1      4    124
# 41      2    13     1      2    222
# 42      3    29     0     10     54
# 43      3    37     0      5     85
# 44      3    24     0      1    100
# 45      3    21     1     10    123
# 46      3    16     1      4    143
# 47      3    11     1      2    333
# 48      4    32     0     10     99
# 49      4    39     0      5    150
# 50      4    21     0      1    180
# 51      4    21     1     10    222
# 52      4    18     1      4    180
# 53      4    12     1      2    444
# 54      5    32     0     10    150
# 55      5    39     0      5    180
# 56      5    24     0      1    189
# 57      5    21     1     10    235
# 58      5    18     1      4    265
# 59      5    12     1      2    555

# %%
data.columns
# Out:
# Index(['miles', 'temp', 'rain', 'ncabs', 'price'], dtype='object')

# %%
x=data[["ncabs"]]
y=data["price"]

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
m=model.coef_
b=model.intercept_
print(m,b)
# Out:
# [-12.41110992] 224.9101787434443

# %%
y_pred=model.predict(x)
y_pred
# Out:
# array([100.79907952, 162.85462913, 212.49906882, 100.79907952,
#        175.26573906, 200.0879589 , 100.79907952, 162.85462913,
#        212.49906882, 100.79907952, 175.26573906, 200.0879589 ,
#        100.79907952, 162.85462913, 212.49906882, 100.79907952,
#        175.26573906, 200.0879589 , 100.79907952, 162.85462913,
#        212.49906882, 100.79907952, 175.26573906, 200.0879589 ,
#        100.79907952, 162.85462913, 212.49906882, 100.79907952,
#        175.26573906, 200.0879589 ,  88.3879696 , 175.26573906,
#        212.49906882,  88.3879696 , 150.44351921, 187.67684898,
#         88.3879696 , 162.85462913, 212.49906882, 100.79907952,
#        175.26573906, 200.0879589 , 100.79907952, 162.85462913,
#        212.49906882, 100.79907952, 175.26573906, 200.0879589 ,
#        100.79907952, 162.85462913, 212.49906882, 100.79907952,
#        175.26573906, 200.0879589 , 100.79907952, 162.85462913,
#        212.49906882, 100.79907952, 175.26573906, 200.0879589 ])

# %%
print("MSE=",mean_squared_error(y,y_pred))
print("RMSE=", np.sqrt(mean_squared_error(y,y_pred)))
print("MAE=",mean_absolute_error(y,y_pred))
print("MAPE=", mean_absolute_percentage_error(y,y_pred))
# Out:
# MSE= 12133.72323165293
# RMSE= 110.15318076048885
# MAE= 80.58182097113702
# MAPE= 83.78225074689453

# %%
def Liner_Best_Fit(x,y):
    model=LinearRegression()
    model.fit(x,y)
    y_pred=model.predict(x)
    print("MSE=",mean_squared_error(y,y_pred))
    print("RMSE=", np.sqrt(mean_squared_error(y,y_pred)))
    print("MAE=",mean_absolute_error(y,y_pred))
    print("MAPE=", mean_absolute_percentage_error(y,y_pred))
def mean_absolute_percentage_error(y, y_pred): 
    y, y_pred = np.array(y), np.array(y_pred)
    return np.mean(np.abs((y - y_pred) / y)) * 100

# %%
Liner_Best_Fit(x,y)
# Out:
# MSE= 12133.72323165293
# RMSE= 110.15318076048885
# MAE= 80.58182097113702
# MAPE= 83.78225074689453

# %%
plt.scatter(x,y, color='black')
plt.plot(x,y_pred,color='b')
plt.show()
